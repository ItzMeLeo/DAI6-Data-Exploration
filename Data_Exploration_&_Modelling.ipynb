# %% [markdown]
# <a href="https://colab.research.google.com/github/ItzMeLeo/DAI6-Data-Exploration/blob/main/Data_Exploration_%26_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd

# %% [markdown]
# # Loading and Parsing
# Loading the data and parsing it into the correct format.

# %%
# Cloning my repository from GitHub to get the csv
# !git clone https://github.com/ItzMeLeo/DAI6-Data-Exploration.git
# Out:
# Cloning into 'DAI6-Data-Exploration'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 9.36 MiB | 22.82 MiB/s, done.

# %%
# Changing the current working directory
base_dir = "/content/DAI6-Data-Exploration"
os.chdir(base_dir)

os.getcwd()
# Out:
# '/content/DAI6-Data-Exploration'

# %%
# Loading the data into a Pandas DataFrame
data = pd.read_csv("data/Data.csv")

data.head(10)
# Out:
#             Unnamed: 0   InputC1   InputC2   InputC3   InputC4  InputC5  \
# 0  2022-01-01 00:00:00  18.49650  18.81396  100.0696  618.6791      NaN
# 1  2022-01-01 00:05:00  18.49731  18.70401  100.0715  613.7349      NaN
# 2  2022-01-01 00:10:00  18.49693  18.59405  100.0733  608.7906      NaN
# 3  2022-01-01 00:15:00  18.49603  18.48410  100.0751  603.8464      NaN
# 4  2022-01-01 00:20:00  18.49512  18.37415  100.0770  598.9022      NaN
# 5  2022-01-01 00:25:00  18.49422  18.26419  100.0788  593.9580      NaN
# 6  2022-01-01 00:30:00  18.49332  18.15424  100.0806  589.0138      NaN
# 7  2022-01-01 00:35:00  18.49242  18.04429  100.0825  584.0696      NaN
# 8  2022-01-01 00:40:00  18.49152  17.93433  100.0843  579.1254      NaN
# 9  2022-01-01 00:45:00  18.49061  17.82438  100.0861  574.1812      NaN
#
#     InputC6   InputC7   InputC8   InputC9  ...   InputA4   InputA5   InputA6  \
# 0  1931.360  7.272931  1878.295  1.549485  ...  60.10090  7.385031  7.081979
# ...

# %% [markdown]
# # General Statistics
# - mean,
# - mode,
# - std,
# - % missing values,
# etc.
#
# What do we learn from these statistics?

# %%
data.describe()
# Out:
#             InputC1       InputC2       InputC3       InputC4       InputC5  \
# count  71948.000000  70943.000000  71116.000000  76396.000000  67461.000000
# mean      19.325297     29.442883     93.863525    780.417599     26.561597
# std        3.070935     14.328902     12.396636    302.515266     24.441761
# min       15.776370     -3.444384     -3.925755      0.000000     16.312110
# 25%       17.417635     21.397670     89.799840    558.980425     17.379560
# 50%       18.035935     29.123960     99.758640    729.260500     17.498360
# 75%       18.547920     36.778240    100.079000   1006.964500     18.246240
# max       25.530860    515.131300    248.376300   1557.484000     95.200650
#
#             InputC6       InputC7       InputC8       InputC9      InputC10  \
# count  70914.000000  70852.000000  70828.000000  70880.000000  70802.000000
# mean    1642.565742      7.301294   1828.115365      1.508127     26.336182
# ...

# %%
# Checking the amount of NaNs per column
nans = data.isna().sum()
nans
# Out:
# Unnamed: 0        0
# InputC1        4526
# InputC2        5531
# InputC3        5358
# InputC4          78
# InputC5        9013
# InputC6        5560
# InputC7        5622
# InputC8        5646
# InputC9        5594
# InputC10       5672
# InputE1        5603
# InputE2        1887
# InputE3       43354
# InputD1        4551
# InputD2        5284
# InputD3        5336
# InputD4          76
# InputD5       10121
# InputD6        5593
# InputD7        5346
# InputD8        5588
# InputD9        1587
# InputD10       5582
# InputA1         724
# InputA2       25422
# InputA3         169
# InputA4        9624
# InputA5        7778
# InputA6        5589
# InputB1        3794
# InputB2        3775
# InputB3          90
# InputB4        9525
# InputB5       33308
# InputB6        3855
# Target         6188
# dtype: int64

# %%
# Percentage of missing values per column
percent_missing = nans * 100 / len(data)
percent_missing
# Out:
# Unnamed: 0     0.000000
# InputC1        5.918351
# InputC2        7.232523
# InputC3        7.006303
# InputC4        0.101995
# InputC5       11.785705
# InputC6        7.270445
# InputC7        7.351518
# InputC8        7.382901
# InputC9        7.314904
# InputC10       7.416900
# InputE1        7.326673
# InputE2        2.467505
# InputE3       56.691163
# InputD1        5.951042
# InputD2        6.909538
# InputD3        6.977535
# InputD4        0.099380
# InputD5       13.234563
# InputD6        7.313597
# InputD7        6.990611
# InputD8        7.307059
# InputD9        2.075215
# InputD10       7.299213
# InputA1        0.946727
# InputA2       33.242671
# InputA3        0.220990
# InputA4       12.584669
# InputA5       10.170777
# InputA6        7.308366
# InputB1        4.961163
# InputB2        4.936318
# InputB3        0.117687
# InputB4       12.455214
# InputB5       43.554672
# InputB6        5.040929
# Target         8.091639
# dtype: float64

# %% [markdown]
# # Outliers
# Exploring the outliers.
#
# ## Exploring Outliers
# Explaining why certain data is treated as an outlier, e.g. because it is physically impossible.

# %% [markdown]
# ## Removing Outliers
# Explaining how to remove the outliers.

# %% [markdown]
# # Data Distributions
# Exploring the data distributions.

# %% [markdown]
# # Time Series Analysis
# Example: seasonality.

# %% [markdown]
# # Correlations
#
# ## Linear Correlations
# Exploring the correlations between all the variables, including target.

# %% [markdown]
# ## Target Correlations
# Exploring the correlations (not only linear) with the other variables.

# %% [markdown]
# # Preprocessing
# A pipeline that converts the raw data into the data needed by the model.

# %% [markdown]
# # Modelling
#
# ## Choice of Model
# Why was this particular model chosen to solve the use case?

# %% [markdown]
# ## Train-test split
# Stating the train-test split.

# %% [markdown]
# ## Training the Model
# Training the AI-Model.

# %% [markdown]
# ## Hyperparametertuning

# %% [markdown]
# # Results
# Discussing the performance of the AI-Model.

# %% [markdown]
# ## If I had more time, ...
#
# ### what would I do differently?
#
# ### where would I spend more time on to improve the result?
#
# ## Other reflections
